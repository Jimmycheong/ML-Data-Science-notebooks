# %% [markdown]
# # Kernels (Spatial Filters)
#
# References:
# - https://developer.apple.com/library/content/documentation/Performance/Conceptual/vImage/ConvolutionOperations/ConvolutionOperations.html
# - https://en.wikipedia.org/wiki/Kernel_(image_processing)

# %% [markdown]
# ## 1. Original

# %%
import numpy as np
from scipy import signal 
from scipy import misc 
import matplotlib.pyplot as plt
from PIL import Image

im = Image.open("characters/fox.jpg")
image_gr = im.convert('L')
arr = np.asarray(image_gr)

#Activating matplotlib for Ipython
# %matplotlib inline

print('GRADIENT MAGNITUDE - Feature map')

fig, aux = plt.subplots(figsize=(5,5))
aux.imshow(np.absolute(arr), cmap='gray')
# Out:
# GRADIENT MAGNITUDE - Feature map

# %%
import numpy as np
from scipy import signal 
from scipy import misc 
import matplotlib.pyplot as plt
from PIL import Image

im = Image.open("characters/fox.jpg")
image_gr = im.convert('L')
arr = np.asarray(image_gr)

kernel = np.array([
                    [-1,-1,-1],
                    [0,0,0],
                    [1,1,1],
                            ])

grad = signal.convolve2d(arr, kernel, mode='same', boundary='symm')

#Activating matplotlib for Ipython
# %matplotlib inline

print('GRADIENT MAGNITUDE - Feature map')

fig, aux = plt.subplots(figsize=(5,5))
aux.imshow(np.absolute(grad), cmap='gray')
# Out:
# GRADIENT MAGNITUDE - Feature map

# %% [markdown]
# ## Gaussian blur filter

# %%
im = Image.open("characters/fox.jpg")
image_gr = im.convert('L')
arr = np.asarray(image_gr)

kernel = np.array([
                    [1,2,1],
                    [2,4,2],
                    [1,2,1],
                            ])

grad = signal.convolve2d(arr, kernel, mode='same', boundary='symm')

#Activating matplotlib for Ipython
# %matplotlib inline

print('GRADIENT MAGNITUDE - Feature map')

fig, aux = plt.subplots(figsize=(5,5))
aux.imshow(np.absolute(grad), cmap='gray')
# Out:
# GRADIENT MAGNITUDE - Feature map

# %%
im = Image.open("characters/fox.jpg")
image_gr = im.convert('L')
arr = np.asarray(image_gr)

kernel = np.array([
                    [0,1,0],
                    [1,-4,1],
                    [0,1,0],
                            ])

grad = signal.convolve2d(arr, kernel, mode='same', boundary='symm')

#Activating matplotlib for Ipython
# %matplotlib inline

print('GRADIENT MAGNITUDE - Feature map')

fig, aux = plt.subplots(figsize=(5,5))
aux.imshow(np.absolute(grad), cmap='gray')
# Out:
# GRADIENT MAGNITUDE - Feature map

# %% [markdown]
# # Edge detection

# %%
im = Image.open("characters/fox.jpg")
image_gr = im.convert('L')
arr = np.asarray(image_gr)

kernel = np.array([
                    [-1,-1,-1],
                    [-1,8,-1],
                    [-1,-1,-1],
                            ])

grad = signal.convolve2d(arr, kernel, mode='same', boundary='symm')

#Activating matplotlib for Ipython
# %matplotlib inline

print('GRADIENT MAGNITUDE - Feature map')

fig, aux = plt.subplots(figsize=(5,5))
aux.imshow(np.absolute(grad), cmap='gray')
# Out:
# GRADIENT MAGNITUDE - Feature map

# %% [markdown]
# ## Sharpen

# %%
im = Image.open("characters/fox.jpg")
image_gr = im.convert('L')
arr = np.asarray(image_gr)

kernel = np.array([
                    [0,-1,0],
                    [-1,5,-1],
                    [0,-1,0],
                            ])

grad = signal.convolve2d(arr, kernel, mode='same', boundary='symm')

#Activating matplotlib for Ipython
# %matplotlib inline

print('GRADIENT MAGNITUDE - Feature map')

fig, aux = plt.subplots(figsize=(5,5))
aux.imshow(np.absolute(grad), cmap='gray')
# Out:
# GRADIENT MAGNITUDE - Feature map
